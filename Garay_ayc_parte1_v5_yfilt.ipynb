# %% [markdown]
# <a href="https://colab.research.google.com/github/carolina-garay/AnalisisYCuracion_Grupo32/blob/carolina_Garay_AyC/Garay_ayc_parte1_v5_yfilt.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Diplomatura en Ciencia de Datos, Aprendizaje Automático y sus Aplicaciones**
#
# **Exploración y Curación de Datos**
#
# *Edición 2022*
#
# ----
#
# # Trabajo práctico entregable - parte 1
# Garay Carolina
#
# En esta notebook, vamos a cargar el conjunto de datos de [la compentencia Kaggle](https://www.kaggle.com/dansbecker/melbourne-housing-snapshot) sobre estimación de precios de ventas de propiedades en Melbourne, Australia.
#
# Utilizaremos el conjunto de datos reducido producido por [DanB](https://www.kaggle.com/dansbecker). Hemos subido una copia a un servidor de la Universidad Nacional de Córdoba para facilitar su acceso remoto.

# %%
# Setup
#!pip install pandas_profiling==2.8.0
# !pip install pandas==1.2.0
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting pandas==1.2.0
#   Downloading pandas-1.2.0-cp37-cp37m-manylinux1_x86_64.whl (9.9 MB)
#      |████████████████████████████████| 9.9 MB 4.4 MB/s
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.7/dist-packages (from pandas==1.2.0) (2.8.2)
# Requirement already satisfied: pytz>=2017.3 in /usr/local/lib/python3.7/dist-packages (from pandas==1.2.0) (2022.1)
# Requirement already satisfied: numpy>=1.16.5 in /usr/local/lib/python3.7/dist-packages (from pandas==1.2.0) (1.21.6)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.7/dist-packages (from python-dateutil>=2.7.3->pandas==1.2.0) (1.15.0)
# Installing collected packages: pandas
#   Attempting uninstall: pandas
#     Found existing installation: pandas 1.3.5
#     Uninstalling pandas-1.3.5:
#       Successfully uninstalled pandas-1.3.5
# Successfully installed pandas-1.2.0

# %%
# !pip install python-decouple
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting python-decouple
#   Downloading python_decouple-3.6-py3-none-any.whl (9.9 kB)
# Installing collected packages: python-decouple
# Successfully installed python-decouple-3.6

# %%
import io
import matplotlib.pyplot as plt
import gdown

import seaborn as sns
sns.set_context('talk')

from decouple import config
from sqlalchemy import create_engine, text

import plotly
plotly.__version__
# Make sure it's 4.14.3
# Out:
# '5.5.0'

# %% [markdown]
# ## Ejercicio 1 SQL:
#
# 1. Crear una base de datos en SQLite utilizando la libreria [SQLalchemy](https://stackoverflow.com/questions/2268050/execute-sql-from-file-in-sqlalchemy).
# https://docs.sqlalchemy.org/en/14/core/engines.html#sqlite
#
# 2. Ingestar los datos provistos en 'https://cs.famaf.unc.edu.ar/~mteruel/datasets/diplodatos/melb_data.csv' en una tabla y el dataset generado en clase con datos de airbnb y sus precios por codigo postal en otra.
#
# 3. Implementar consultas en SQL que respondan con la siguiente información:
#
#     - cantidad de registros totales por ciudad.
#     - cantidad de registros totales por barrio y ciudad.
#
# 4. Combinar los datasets de ambas tablas ingestadas utilizando el comando JOIN de SQL  para obtener un resultado similar a lo realizado con Pandas en clase.

# %% [markdown]
# ##EJERCICIO1_Respuestas

# %% [markdown]
# 1.1 Crear una base de datos en SQLite utilizando la libreria [SQLalchemy](https://stackoverflow.com/questions/2268050/execute-sql-from-file-in-sqlalchemy).
# https://docs.sqlalchemy.org/en/14/core/engines.html#sqlite

# %%
#Luego de realizar una rápida exploración de los datos
#establecemos conexión a la base de dstos
#Aquí el módulo sqlite3 proporciona una interfaz sencilla para interactuar con bases de datos SQLite.
engine = create_engine('sqlite:///sysarmy.sqlite3', echo=True)

# %% [markdown]
# 1.2 Ingestar los datos provistos en 'https://cs.famaf.unc.edu.ar/~mteruel/datasets/diplodatos/melb_data.csv' en una tabla y el dataset generado en clase con datos de airbnb y sus precios por codigo postal en otra.

# %%
import numpy as np
import pandas as pd

# %%
melb_df = pd.read_csv('https://cs.famaf.unc.edu.ar/~mteruel/datasets/diplodatos/melb_data.csv')

# %%
melb_df.to_sql('melb_sql', con=engine, if_exists="replace")
# Out:
# 2022-05-29 03:23:30,373 INFO sqlalchemy.engine.Engine PRAGMA main.table_info("melb_sql")
# 2022-05-29 03:23:30,375 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2022-05-29 03:23:30,378 INFO sqlalchemy.engine.Engine PRAGMA temp.table_info("melb_sql")
# 2022-05-29 03:23:30,380 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2022-05-29 03:23:30,391 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2022-05-29 03:23:30,395 INFO sqlalchemy.engine.Engine
# CREATE TABLE melb_sql (
# 	"index" BIGINT,
# 	"Suburb" TEXT,
# 	"Address" TEXT,
# 	"Rooms" BIGINT,
# 	"Type" TEXT,
# 	"Price" FLOAT,
# 	"Method" TEXT,
# 	"SellerG" TEXT,
# 	"Date" TEXT,
# 	"Distance" FLOAT,
# 	"Postcode" FLOAT,
# 	"Bedroom2" FLOAT,
# 	"Bathroom" FLOAT,
# 	"Car" FLOAT,
# 	"Landsize" FLOAT,
# 	"BuildingArea" FLOAT,
# 	"YearBuilt" FLOAT,
# 	"CouncilArea" TEXT,
# 	"Lattitude" FLOAT,
# 	"Longtitude" FLOAT,
# 	"Regionname" TEXT,
# 	"Propertycount" FLOAT
# )
#
#
# 2022-05-29 03:23:30,397 INFO sqlalchemy.engine.Engine [no key 0.00249s] ()
# 2022-05-29 03:23:30,416 INFO sqlalchemy.engine.Engine CREATE INDEX ix_melb_sql_index ON melb_sql ("index")
# 2022-05-29 03:23:30,418 INFO sqlalchemy.engine.Engine [no key 0.00257s] ()
# 2022-05-29 03:23:30,434 INFO sqlalchemy.engine.Engine COMMIT
# 2022-05-29 03:23:30,462 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2022-05-29 03:23:30,959 INFO sqlalchemy.engine.Engine INSERT INTO melb_sql ("index", "Suburb", "Address", "Rooms", "Type", "Price", "Method", "SellerG", "Date", "Distance", "Postcode", "Bedroom2", "Bathroom", "Car", "Landsize", "BuildingArea", "YearBuilt", "CouncilArea", "Lattitude", "Longtitude", "Regionname", "Propertycount") VALUES (?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?)
# 2022-05-29 03:23:30,973 INFO sqlalchemy.engine.Engine [generated in 0.44894s] ((0, 'Abbotsford', '85 Turner St', 2, 'h', 1480000.0, 'S', 'Biggin', '3/12/2016', 2.5, 3067.0, 2.0, 1.0, 1.0, 202.0, None, None, 'Yarra', -37.7996, 144.9984, 'Northern Metropolitan', 4019.0), (1, 'Abbotsford', '25 Bloomburg St', 2, 'h', 1035000.0, 'S', 'Biggin', '4/02/2016', 2.5, 3067.0, 2.0, 1.0, 0.0, 156.0, 79.0, 1900.0, 'Yarra', -37.8079, 144.9934, 'Northern Metropolitan', 4019.0), (2, 'Abbotsford', '5 Charles St', 3, 'h', 1465000.0, 'SP', 'Biggin', '4/03/2017', 2.5, 3067.0, 3.0, 2.0, 0.0, 134.0, 150.0, 1900.0, 'Yarra', -37.8093, 144.9944, 'Northern Metropolitan', 4019.0), (3, 'Abbotsford', '40 Federation La', 3, 'h', 850000.0, 'PI', 'Biggin', '4/03/2017', 2.5, 3067.0, 3.0, 2.0, 1.0, 94.0, None, None, 'Yarra', -37.7969, 144.9969, 'Northern Metropolitan', 4019.0), (4, 'Abbotsford', '55a Park St', 4, 'h', 1600000.0, 'VB', 'Nelson', '4/06/2016', 2.5, 3067.0, 3.0, 1.0, 2.0, 120.0, 142.0, 2014.0, 'Yarra', -37.8072, 144.9941, 'Northern Metropolitan', 4019.0), (5, 'Abbotsford', '129 Charles St', 2, 'h', 941000.0, 'S', 'Jellis', '7/05/2016', 2.5, 3067.0, 2.0, 1.0, 0.0, 181.0, None, None, 'Yarra', -37.8041, 144.9953, 'Northern Metropolitan', 4019.0), (6, 'Abbotsford', '124 Yarra St', 3, 'h', 1876000.0, 'S', 'Nelson', '7/05/2016', 2.5, 3067.0, 4.0, 2.0, 0.0, 245.0, 210.0, 1910.0, 'Yarra', -37.8024, 144.9993, 'Northern Metropolitan', 4019.0), (7, 'Abbotsford', '98 Charles St', 2, 'h', 1636000.0, 'S', 'Nelson', '8/10/2016', 2.5, 3067.0, 2.0, 1.0, 2.0, 256.0, 107.0, 1890.0, 'Yarra', -37.806, 144.9954, 'Northern Metropolitan', 4019.0)  ... displaying 10 of 13580 total bound parameter sets ...  (13578, 'Williamstown', '96 Verdon St', 4, 'h', 2500000.0, 'PI', 'Sweeney', '26/08/2017', 6.8, 3016.0, 4.0, 1.0, 5.0, 866.0, 157.0, 1920.0, None, -37.85908, 144.89299, 'Western Metropolitan', 6380.0), (13579, 'Yarraville', '6 Agnes St', 4, 'h', 1285000.0, 'SP', 'Village', '26/08/2017', 6.3, 3013.0, 4.0, 1.0, 1.0, 362.0, 112.0, 1920.0, None, -37.81188, 144.88449, 'Western Metropolitan', 6543.0))
# 2022-05-29 03:23:31,080 INFO sqlalchemy.engine.Engine COMMIT

# %%
#Lectura del dataset airbnb
#Descargamos el archivo generado en clase desde drive de Carolina 
# !gdown https://drive.google.com/file/d/1sUR2Odse85vmQn62yYaEsaUCRJo28Nj2/view?usp=sharing --fuzzy

airbnb_df = pd.read_csv('/content/airbnb_price_by_zipcode.csv')
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1sUR2Odse85vmQn62yYaEsaUCRJo28Nj2
# To: /content/airbnb_price_by_zipcode.csv
# 100% 10.1k/10.1k [00:00<00:00, 11.0MB/s]

# %%
airbnb_df.to_sql('airbnb_sql', con=engine, if_exists="replace")
# Out:
# 2022-05-29 03:23:32,694 INFO sqlalchemy.engine.Engine PRAGMA main.table_info("airbnb_sql")
# 2022-05-29 03:23:32,696 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2022-05-29 03:23:32,701 INFO sqlalchemy.engine.Engine PRAGMA temp.table_info("airbnb_sql")
# 2022-05-29 03:23:32,703 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2022-05-29 03:23:32,711 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2022-05-29 03:23:32,717 INFO sqlalchemy.engine.Engine
# CREATE TABLE airbnb_sql (
# 	"index" BIGINT,
# 	zipcode FLOAT,
# 	airbnb_price_mean FLOAT,
# 	airbnb_record_count BIGINT,
# 	airbnb_weekly_price_mean FLOAT,
# 	airbnb_monthly_price_mean FLOAT
# )
#
#
# 2022-05-29 03:23:32,719 INFO sqlalchemy.engine.Engine [no key 0.00210s] ()
# 2022-05-29 03:23:32,744 INFO sqlalchemy.engine.Engine CREATE INDEX ix_airbnb_sql_index ON airbnb_sql ("index")
# 2022-05-29 03:23:32,747 INFO sqlalchemy.engine.Engine [no key 0.00231s] ()
# 2022-05-29 03:23:32,764 INFO sqlalchemy.engine.Engine COMMIT
# 2022-05-29 03:23:32,771 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2022-05-29 03:23:32,781 INFO sqlalchemy.engine.Engine INSERT INTO airbnb_sql ("index", zipcode, airbnb_price_mean, airbnb_record_count, airbnb_weekly_price_mean, airbnb_monthly_price_mean) VALUES (?, ?, ?, ?, ?, ?)
# 2022-05-29 03:23:32,784 INFO sqlalchemy.engine.Engine [generated in 0.00713s] ((0, 2010.0, 40.0, 1, None, None), (1, 2134.0, 50.0, 1, None, None), (2, 2582.0, 104.0, 1, None, None), (3, 3000.0, 150.5043065043065, 3367, 918.7389558232932, 3407.204651162791), (4, 3001.0, 132.5, 2, None, None), (5, 3002.0, 200.9796954314721, 197, 956.3793103448276, 3712.714285714286), (6, 3003.0, 130.20599250936328, 267, 760.2, 2629.5), (7, 3004.0, 158.271978021978, 728, 1061.1714285714286, 3759.925925925926)  ... displaying 10 of 247 total bound parameter sets ...  (245, 9540.0, 245.0, 1, None, None), (246, 30122.0, 75.0, 1, 525.0, 2281.0))
# 2022-05-29 03:23:32,791 INFO sqlalchemy.engine.Engine COMMIT

# %%
#Visualización de columnas de los dataframe airbnb_df y melb_df
print("Columnas de airbnb_df:",airbnb_df.columns)
print("Columnas de melb_df:",melb_df.columns)
# Out:
# Columnas de airbnb_df: Index(['zipcode', 'airbnb_price_mean', 'airbnb_record_count',
#        'airbnb_weekly_price_mean', 'airbnb_monthly_price_mean'],
#       dtype='object')
# Columnas de melb_df: Index(['Suburb', 'Address', 'Rooms', 'Type', 'Price', 'Method', 'SellerG',
#        'Date', 'Distance', 'Postcode', 'Bedroom2', 'Bathroom', 'Car',
#        'Landsize', 'BuildingArea', 'YearBuilt', 'CouncilArea', 'Lattitude',
#        'Longtitude', 'Regionname', 'Propertycount'],
#       dtype='object')

# %%
 #Recuento de filas de los dataframe
 print(len(airbnb_df))
 print(len(melb_df))
# Out:
# 247
# 13580

# %% [markdown]
# 3. Implementar consultas en SQL que respondan con la siguiente información:
#
#     - cantidad de registros totales por ciudad.
#     - cantidad de registros totales por barrio y ciudad.

# %%
# Cantidad de registros totales por ciudad en el dataframe melb_df
query1 = "SELECT CouncilArea, COUNT(CouncilArea) FROM melb_sql GROUP BY CouncilArea"

# Cantidad de registros totales por barrio y ciudad en el dataframe melb_df
query2 = "SELECT CouncilArea, Suburb, COUNT(Suburb) FROM melb_sql GROUP BY Suburb ORDER BY CouncilArea"

# %%
#Lista con las consultas 
queries = [query1, query2]

# %%
with engine.connect() as con:
    for query in queries:
      rs = con.execute(query)
      print(query)
      for row in rs:
          print(row)

      print('\n\n')
# Out:
# 2022-05-29 03:23:32,890 INFO sqlalchemy.engine.Engine SELECT CouncilArea, COUNT(CouncilArea) FROM melb_sql GROUP BY CouncilArea
# 2022-05-29 03:23:32,893 INFO sqlalchemy.engine.Engine [raw sql] ()
# SELECT CouncilArea, COUNT(CouncilArea) FROM melb_sql GROUP BY CouncilArea
# (None, 0)
# ('Banyule', 594)
# ('Bayside', 489)
# ('Boroondara', 1160)
# ('Brimbank', 424)
# ('Cardinia', 8)
# ('Casey', 38)
# ('Darebin', 934)
# ('Frankston', 53)
# ('Glen Eira', 848)
# ('Greater Dandenong', 52)
# ('Hobsons Bay', 434)
# ('Hume', 164)
# ('Kingston', 207)
# ('Knox', 80)
# ('Macedon Ranges', 7)
# ('Manningham', 311)
# ('Maribyrnong', 692)
# ('Maroondah', 80)
# ('Melbourne', 470)
# ('Melton', 66)
# ('Monash', 333)
# ('Moonee Valley', 997)
# ('Moorabool', 1)
# ('Moreland', 1163)
# ('Nillumbik', 36)
# ('Port Phillip', 628)
# ('Stonnington', 719)
# ('Unavailable', 1)
# ('Whitehorse', 304)
# ('Whittlesea', 167)
# ('Wyndham', 86)
# ('Yarra', 647)
# ('Yarra Ranges', 18)
#
#
#
# 2022-05-29 03:23:32,933 INFO sqlalchemy.engine.Engine SELECT CouncilArea, Suburb, COUNT(Suburb) FROM melb_sql GROUP BY Suburb ORDER BY CouncilArea
# 2022-05-29 03:23:32,935 INFO sqlalchemy.engine.Engine [raw sql] ()
# SELECT CouncilArea, Suburb, COUNT(Suburb) FROM melb_sql GROUP BY Suburb ORDER BY CouncilArea
# (None, 'Abbotsford', 56)
# (None, 'Aberfeldie', 44)
# (None, 'Airport West', 67)
# (None, 'Albanvale', 6)
# (None, 'Albert Park', 69)
# (None, 'Albion', 41)
# (None, 'Alphington', 34)
# (None, 'Altona', 74)
# (None, 'Altona Meadows', 6)
# (None, 'Altona North', 56)
# (None, 'Ardeer', 3)
# (None, 'Armadale', 95)
# (None, 'Ascot Vale', 130)
# (None, 'Ashburton', 60)
# (None, 'Ashwood', 46)
# (None, 'Aspendale', 7)
# (None, 'Aspendale Gardens', 4)
# (None, 'Attwood', 1)
# (None, 'Avondale Heights', 74)
# (None, 'Balaclava', 27)
# (None, 'Balwyn', 107)
# (None, 'Balwyn North', 171)
# (None, 'Bayswater', 14)
# (None, 'Bayswater North', 8)
# (None, 'Beaumaris', 18)
# (None, 'Bellfield', 16)
# (None, 'Bentleigh', 139)
# (None, 'Bentleigh East', 249)
# (None, 'Berwick', 13)
# (None, 'Black Rock', 12)
# (None, 'Blackburn', 21)
# (None, 'Blackburn North', 14)
# (None, 'Blackburn South', 12)
# (None, 'Bonbeach', 4)
# (None, 'Boronia', 14)
# (None, 'Box Hill', 59)
# (None, 'Braybrook', 46)
# (None, 'Briar Hill', 8)
# (None, 'Brighton', 186)
# (None, 'Brighton East', 138)
# (None, 'Broadmeadows', 23)
# (None, 'Brooklyn', 9)
# (None, 'Brunswick', 222)
# (None, 'Brunswick East', 88)
# (None, 'Brunswick West', 110)
# (None, 'Bulleen', 71)
# (None, 'Bundoora', 36)
# (None, 'Burnside', 2)
# (None, 'Burnside Heights', 3)
# (None, 'Burwood', 84)
# (None, 'Burwood East', 16)
# (None, 'Camberwell', 132)
# (None, 'Campbellfield', 4)
# (None, 'Canterbury', 54)
# (None, 'Carlton', 51)
# (None, 'Carlton North', 48)
# (None, 'Carnegie', 146)
# (None, 'Caroline Springs', 11)
# (None, 'Carrum Downs', 12)
# (None, 'Caulfield East', 9)
# (None, 'Caulfield South', 47)
# (None, 'Chadstone', 35)
# (None, 'Chelsea', 5)
# (None, 'Chelsea Heights', 4)
# (None, 'Cheltenham', 46)
# (None, 'Clarinda', 4)
# (None, 'Clayton', 13)
# (None, 'Clayton South', 11)
# (None, 'Clifton Hill', 57)
# (None, 'Coburg', 190)
# (None, 'Coburg North', 56)
# (None, 'Collingwood', 65)
# (None, 'Coolaroo', 4)
# (None, 'Craigieburn', 47)
# (None, 'Cranbourne', 3)
# (None, 'Cremorne', 25)
# (None, 'Croydon', 33)
# (None, 'Croydon Hills', 4)
# (None, 'Croydon North', 7)
# (None, 'Dallas', 6)
# (None, 'Dandenong', 13)
# (None, 'Dandenong North', 16)
# (None, 'Deer Park', 14)
# (None, 'Delahey', 6)
# (None, 'Derrimut', 5)
# (None, 'Diamond Creek', 6)
# (None, 'Dingley Village', 21)
# (None, 'Doncaster', 116)
# (None, 'Doncaster East', 41)
# (None, 'Donvale', 13)
# (None, 'Doreen', 6)
# (None, 'Doveton', 7)
# (None, 'Eaglemont', 23)
# (None, 'Edithvale', 9)
# (None, 'Elsternwick', 61)
# (None, 'Eltham', 25)
# (None, 'Eltham North', 13)
# (None, 'Elwood', 131)
# (None, 'Epping', 52)
# (None, 'Essendon', 220)
# (None, 'Essendon North', 22)
# (None, 'Fairfield', 43)
# (None, 'Fawkner', 102)
# (None, 'Ferntree Gully', 22)
# (None, 'Fitzroy', 59)
# (None, 'Fitzroy North', 93)
# (None, 'Flemington', 62)
# (None, 'Footscray', 132)
# (None, 'Forest Hill', 22)
# (None, 'Frankston', 24)
# (None, 'Frankston North', 4)
# (None, 'Frankston South', 16)
# (None, 'Gisborne', 8)
# (None, 'Gladstone Park', 20)
# (None, 'Glen Huntly', 17)
# (None, 'Glen Iris', 195)
# (None, 'Glen Waverley', 45)
# (None, 'Glenroy', 159)
# (None, 'Gowanbrae', 24)
# (None, 'Greensborough', 36)
# (None, 'Greenvale', 17)
# (None, 'Hadfield', 62)
# (None, 'Hallam', 5)
# (None, 'Hampton', 130)
# (None, 'Hampton East', 25)
# (None, 'Hampton Park', 4)
# (None, 'Hawthorn', 191)
# (None, 'Hawthorn East', 119)
# (None, 'Heathmont', 16)
# (None, 'Heidelberg', 51)
# (None, 'Heidelberg Heights', 78)
# (None, 'Heidelberg West', 76)
# (None, 'Highett', 27)
# (None, 'Hillside', 18)
# (None, 'Hoppers Crossing', 38)
# (None, 'Huntingdale', 7)
# (None, 'Hurstbridge', 2)
# (None, 'Ivanhoe', 98)
# (None, 'Ivanhoe East', 25)
# (None, 'Jacana', 25)
# (None, 'Kealba', 19)
# (None, 'Keilor', 9)
# (None, 'Keilor Downs', 15)
# (None, 'Keilor East', 121)
# (None, 'Keilor Lodge', 2)
# (None, 'Keilor Park', 22)
# (None, 'Kensington', 117)
# (None, 'Kew', 177)
# (None, 'Kew East', 49)
# (None, 'Keysborough', 11)
# (None, 'Kilsyth', 4)
# (None, 'Kings Park', 5)
# (None, 'Kingsville', 34)
# (None, 'Kooyong', 2)
# (None, 'Lalor', 42)
# (None, 'Langwarrin', 6)
# (None, 'Maidstone', 94)
# (None, 'Malvern', 67)
# (None, 'Malvern East', 117)
# (None, 'Maribyrnong', 96)
# (None, 'McKinnon', 8)
# (None, 'Meadow Heights', 17)
# (None, 'Melton', 12)
# (None, 'Melton South', 18)
# (None, 'Melton West', 8)
# (None, 'Mentone', 26)
# (None, 'Mernda', 9)
# (None, 'Middle Park', 34)
# (None, 'Mill Park', 43)
# (None, 'Mitcham', 30)
# (None, 'Monbulk', 1)
# (None, 'Mont Albert', 34)
# (None, 'Montmorency', 17)
# (None, 'Moonee Ponds', 149)
# (None, 'Moorabbin', 64)
# (None, 'Mooroolbark', 12)
# (None, 'Mordialloc', 18)
# (None, 'Mount Evelyn', 2)
# (None, 'Mount Waverley', 57)
# (None, 'Mulgrave', 29)
# (None, 'Murrumbeena', 82)
# (None, 'Narre Warren', 7)
# (None, 'New Gisborne', 1)
# (None, 'Newport', 137)
# (None, 'Niddrie', 82)
# (None, 'North Melbourne', 81)
# (None, 'North Warrandyte', 2)
# (None, 'Northcote', 188)
# (None, 'Notting Hill', 3)
# (None, 'Nunawading', 20)
# (None, 'Oak Park', 63)
# (None, 'Oakleigh', 47)
# (None, 'Oakleigh East', 11)
# (None, 'Oakleigh South', 58)
# (None, 'Ormond', 83)
# (None, 'Parkdale', 24)
# (None, 'Pascoe Vale', 171)
# (None, 'Plumpton', 1)
# (None, 'Point Cook', 13)
# (None, 'Port Melbourne', 153)
# (None, 'Prahran', 123)
# (None, 'Preston', 239)
# (None, 'Princes Hill', 5)
# (None, 'Reservoir', 359)
# (None, 'Richmond', 260)
# (None, 'Ringwood', 20)
# (None, 'Ringwood East', 12)
# (None, 'Ringwood North', 10)
# (None, 'Rosanna', 61)
# (None, 'Roxburgh Park', 15)
# (None, 'Sandringham', 25)
# (None, 'Scoresby', 8)
# (None, 'Seaford', 14)
# (None, 'Seddon', 62)
# (None, 'South Melbourne', 85)
# (None, 'South Morang', 21)
# (None, 'South Yarra', 202)
# (None, 'Spotswood', 29)
# (None, 'Springvale', 9)
# (None, 'Springvale South', 3)
# (None, 'St Albans', 25)
# (None, 'St Helena', 3)
# (None, 'St Kilda', 162)
# (None, 'Strathmore', 63)
# (None, 'Strathmore Heights', 6)
# (None, 'Sunbury', 38)
# (None, 'Sunshine', 111)
# (None, 'Sunshine North', 68)
# (None, 'Sunshine West', 86)
# (None, 'Surrey Hills', 125)
# (None, 'Tarneit', 10)
# (None, 'Taylors Lakes', 22)
# (None, 'Templestowe', 19)
# (None, 'Templestowe Lower', 92)
# (None, 'The Basin', 4)
# (None, 'Thomastown', 29)
# (None, 'Thornbury', 139)
# (None, 'Toorak', 100)
# (None, 'Truganina', 5)
# (None, 'Tullamarine', 13)
# (None, 'Vermont', 14)
# (None, 'Vermont South', 13)
# (None, 'Viewbank', 41)
# (None, 'Wallan', 1)
# (None, 'Wantirna', 12)
# (None, 'Wantirna South', 22)
# (None, 'Warrandyte', 5)
# (None, 'Waterways', 2)
# (None, 'Watsonia', 52)
# (None, 'Watsonia North', 10)
# (None, 'Werribee', 50)
# (None, 'West Footscray', 105)
# (None, 'West Melbourne', 31)
# (None, 'Westmeadows', 14)
# (None, 'Wheelers Hill', 26)
# (None, 'Williams Landing', 2)
# (None, 'Williamstown', 107)
# (None, 'Williamstown North', 19)
# (None, 'Windsor', 60)
# (None, 'Wollert', 9)
# (None, 'Wyndham Vale', 4)
# (None, 'Yallambie', 24)
# (None, 'Yarraville', 164)
# ('Banyule', 'Lower Plenty', 5)
# ('Boroondara', 'Deepdene', 2)
# ('Brimbank', 'Cairnlea', 7)
# ('Brimbank', 'Sydenham', 5)
# ('Cardinia', 'Beaconsfield', 2)
# ('Cardinia', 'Beaconsfield Upper', 1)
# ('Cardinia', 'Emerald', 1)
# ('Cardinia', 'Officer', 1)
# ('Cardinia', 'Pakenham', 3)
# ('Casey', 'Cranbourne North', 2)
# ('Casey', 'Endeavour Hills', 5)
# ('Darebin', 'Kingsbury', 13)
# ('Frankston', 'Sandhurst', 1)
# ('Frankston', 'Skye', 2)
# ('Glen Eira', 'Caulfield', 12)
# ('Glen Eira', 'Caulfield North', 35)
# ('Glen Eira', 'Gardenvale', 6)
# ('Greater Dandenong', 'Noble Park', 12)
# ('Hobsons Bay', 'Seabrook', 3)
# ('Hobsons Bay', 'Seaholme', 6)
# ('Hobsons Bay', 'South Kingsville', 22)
# ('Kingston', 'Carrum', 9)
# ('Knox', 'Knoxfield', 4)
# ('Knox', 'Rowville', 10)
# ('Macedon Ranges', 'Bullengarook', 1)
# ('Macedon Ranges', 'Riddells Creek', 1)
# ('Manningham', 'Wonga Park', 1)
# ('Maroondah', 'Croydon South', 1)
# ('Melbourne', 'Docklands', 3)
# ('Melbourne', 'East Melbourne', 22)
# ('Melbourne', 'Melbourne', 46)
# ('Melbourne', 'Parkville', 31)
# ('Melbourne', 'Southbank', 41)
# ('Melton', 'Brookfield', 1)
# ('Melton', 'Diggers Rest', 2)
# ('Melton', 'Kurunjang', 4)
# ('Melton', 'Rockbank', 1)
# ('Melton', 'Taylors Hill', 7)
# ('Monash', 'Hughesdale', 35)
# ('Moonee Valley', 'Essendon West', 26)
# ('Moonee Valley', 'Travancore', 10)
# ('Moorabool', 'Bacchus Marsh', 1)
# ('Port Phillip', 'Ripponlea', 9)
# ('Whittlesea', 'Whittlesea', 1)
# ('Yarra', 'Burnley', 7)
# ('Yarra Ranges', 'Chirnside Park', 2)
# ('Yarra Ranges', 'Healesville', 1)
# ('Yarra Ranges', 'Montrose', 1)
# ('Yarra Ranges', 'Silvan', 2)
# ('Yarra Ranges', 'Upwey', 1)
# ('Yarra Ranges', 'Yarra Glen', 1)

# %% [markdown]
# 1.4 Combinar los datasets de ambas tablas ingestadas utilizando el comando JOIN de SQL  para obtener un resultado similar a lo realizado con Pandas en clase.

# %%
airbn_melb_df= engine.connect().execute('SELECT * FROM  melb_sql LEFT JOIN airbnb_sql ON melb_sql.Postcode = airbnb_sql.zipcode')
# Out:
# 2022-05-29 03:23:33,118 INFO sqlalchemy.engine.Engine SELECT * FROM  melb_sql LEFT JOIN airbnb_sql ON melb_sql.Postcode = airbnb_sql.zipcode
# 2022-05-29 03:23:33,120 INFO sqlalchemy.engine.Engine [raw sql] ()

# %% [markdown]
# ## Ejercicio 2:
#
# 1. Seleccionar un subconjunto de columnas que les parezcan relevantes al problema de predicción del valor de la propiedad. Justificar las columnas seleccionadas y las que no lo fueron.
#  - Eliminar los valores extremos que no sean relevantes para la predicción de valores de las propiedades.
#
# 2. Agregar información adicional respectiva al entorno de una propiedad a partir del [conjunto de datos de AirBnB](https://www.kaggle.com/tylerx/melbourne-airbnb-open-data?select=cleansed_listings_dec18.csv) utilizado en el práctico.
#   1. Seleccionar qué variables agregar y qué combinaciones aplicar a cada una. Por ejemplo, pueden utilizar solo la columna `price`, o aplicar múltiples transformaciones como la mediana o el mínimo.
#   1. Utilizar la variable zipcode para unir los conjuntos de datos. Sólo incluir los zipcodes que tengan una cantidad mínima de registros (a elección) como para que la información agregada sea relevante.
#   2. Investigar al menos otras 2 variables que puedan servir para combinar los datos, y justificar si serían adecuadas o no. Pueden asumir que cuentan con la ayuda de anotadores expertos para encontrar equivalencias entre barrios o direcciones, o que cuentan con algoritmos para encontrar las n ubicaciones más cercanas a una propiedad a partir de sus coordenadas geográficas. **NO** es necesario que realicen la implementación.
#
# Pueden leer otras columnas del conjunto de AirBnB además de las que están en `interesting_cols`, si les parecen relevantes.

# %% [markdown]
# ##EJERCICIO2_Respuestas

# %% [markdown]
# 1. Seleccionar un subconjunto de columnas que les parezcan relevantes al problema de predicción del valor de la propiedad. Justificar las columnas seleccionadas y las que no lo fueron.
#  - Eliminar los valores extremos que no sean relevantes para la predicción de valores de las propiedades.

# %%
#from pandas_profiling import ProfileReport

# %%
#profile = ProfileReport(melb_df)
#profile

# %% [markdown]
# Basados en el reporte de pandas_profiling seleccionamos las siguientes variables para estudiar el problema de predicción del valor de la propiedad.
# *  YearBuilt
# *  BuildingArea
# *  Car
# *  Price
# *  Postcode
# *  Suburb
# *  Rooms

# %%
melb_new= melb_df[['Regionname', 'Suburb', 'Type', 'YearBuilt','BuildingArea' ,'Car','Price' ,'Postcode','Rooms']]
	
melb_new.head()
# Out:
#               Regionname      Suburb Type  YearBuilt  BuildingArea  Car  \
# 0  Northern Metropolitan  Abbotsford    h        NaN           NaN  1.0
# 1  Northern Metropolitan  Abbotsford    h     1900.0          79.0  0.0
# 2  Northern Metropolitan  Abbotsford    h     1900.0         150.0  0.0
# 3  Northern Metropolitan  Abbotsford    h        NaN           NaN  1.0
# 4  Northern Metropolitan  Abbotsford    h     2014.0         142.0  2.0
#
#        Price  Postcode  Rooms
# 0  1480000.0    3067.0      2
# 1  1035000.0    3067.0      2
# 2  1465000.0    3067.0      3
# 3   850000.0    3067.0      3
# 4  1600000.0    3067.0      4

# %%
#Histograma de la base de datos melb_new
plt.figure(figsize=(15,6))
sns.histplot(melb_new.Price.dropna(), bins=100, color ='red')
plt.ticklabel_format(style='plain')
sns.despine()

# %%
#Histograma de la base de datos melb_new
plt.figure(figsize=(15,6))
sns.histplot(melb_new.YearBuilt, bins=100, color ='red')
plt.ticklabel_format(style='plain')
sns.despine()

# %%
# Filtrado de la base de datos por precios 

melb_newp =  melb_new[(melb_new['Price'] > 200000) & (melb_new['Price'] < 3000000)]
plt.figure(figsize=(15,6))
sns.histplot(melb_newp['Price'].dropna(), bins=150, color ='red')
plt.ticklabel_format(style='plain')
sns.despine()

# %%
#Filtrado de la base de datos por valores extremos Car
melb_newcc =  melb_newp [melb_newp ['Car'] < 7]

#Filtrado de la base de datos por valores extremos YearBuilt
melb_newy  =  melb_newc[melb_newc['YearBuilt'] > 1989]

# %%
melb_newcc.head()
# Out:
#               Regionname      Suburb Type  YearBuilt  BuildingArea  Car  \
# 0  Northern Metropolitan  Abbotsford    h        NaN           NaN  1.0
# 1  Northern Metropolitan  Abbotsford    h     1900.0          79.0  0.0
# 2  Northern Metropolitan  Abbotsford    h     1900.0         150.0  0.0
# 3  Northern Metropolitan  Abbotsford    h        NaN           NaN  1.0
# 4  Northern Metropolitan  Abbotsford    h     2014.0         142.0  2.0
#
#        Price  Postcode  Rooms
# 0  1480000.0    3067.0      2
# 1  1035000.0    3067.0      2
# 2  1465000.0    3067.0      3
# 3   850000.0    3067.0      3
# 4  1600000.0    3067.0      4

# %%
melb_x= melb_newcc[melb_newcc['YearBuilt']<1855]
melb_x
# Out:
#                  Regionname          Suburb Type  YearBuilt  BuildingArea  \
# 2079  Northern Metropolitan     Collingwood    u     1830.0         122.0
# 2554  Northern Metropolitan         Fitzroy    h     1850.0           NaN
# 4843  Southern Metropolitan         Prahran    u     1850.0         101.0
# 5405  Northern Metropolitan        Richmond    h     1850.0         144.0
# 5860  Southern Metropolitan        St Kilda    u     1850.0           3.0
# 9968   Eastern Metropolitan  Mount Waverley    h     1196.0         117.0
#
#       Car      Price  Postcode  Rooms
# 2079  1.0   855000.0    3066.0      2
# 2554  0.0   677000.0    3065.0      2
# 4843  1.0   841000.0    3181.0      2
# 5405  2.0  1600000.0    3121.0      3
# 5860  2.0  1600000.0    3182.0      3
# 9968  4.0  1200000.0    3149.0      3

# %%
melb_x= melb_newcc[melb_newcc['YearBuilt']<1880]
melb_x
# Out:
#                   Regionname           Suburb Type  YearBuilt  BuildingArea  \
# 2079   Northern Metropolitan      Collingwood    u     1830.0        122.00
# 2554   Northern Metropolitan          Fitzroy    h     1850.0           NaN
# 4408   Northern Metropolitan        Northcote    h     1870.0           NaN
# 4580   Northern Metropolitan        Parkville    h     1875.0        172.00
# 4707   Southern Metropolitan   Port Melbourne    h     1863.0        280.00
# 4843   Southern Metropolitan          Prahran    u     1850.0        101.00
# 5405   Northern Metropolitan         Richmond    h     1850.0        144.00
# 5536   Southern Metropolitan  South Melbourne    h     1856.0        232.00
# 5543   Southern Metropolitan  South Melbourne    h     1860.0        153.00
# 5568   Southern Metropolitan  South Melbourne    h     1877.0        260.00
# 5573   Southern Metropolitan  South Melbourne    h     1863.0           NaN
# 5798   Southern Metropolitan         St Kilda    h     1868.0           NaN
# 5860   Southern Metropolitan         St Kilda    u     1850.0          3.00
# 8031   Southern Metropolitan              Kew    t     1872.0          3.00
# 8583   Northern Metropolitan          Carlton    t     1860.0         90.00
# 8712   Northern Metropolitan   West Melbourne    h     1870.0           NaN
# 9968    Eastern Metropolitan   Mount Waverley    h     1196.0        117.00
# 10288  Southern Metropolitan        Glen Iris    u     1875.0         93.00
# 11503  Southern Metropolitan  South Melbourne    h     1860.0        193.74
# 12158  Southern Metropolitan  South Melbourne    h     1857.0           NaN
#
#        Car      Price  Postcode  Rooms
# 2079   1.0   855000.0    3066.0      2
# 2554   0.0   677000.0    3065.0      2
# 4408   2.0  1950000.0    3070.0      4
# 4580   1.0  2200000.0    3052.0      2
# 4707   0.0  2200000.0    3207.0      3
# 4843   1.0   841000.0    3181.0      2
# 5405   2.0  1600000.0    3121.0      3
# 5536   0.0  2260000.0    3205.0      4
# 5543   1.0  2180000.0    3205.0      4
# 5568   2.0  2300000.0    3205.0      3
# 5573   1.0  2525000.0    3205.0      3
# 5798   0.0  2720000.0    3182.0      3
# 5860   2.0  1600000.0    3182.0      3
# 8031   2.0   690000.0    3101.0      3
# 8583   1.0   960000.0    3053.0      2
# 8712   1.0  1750000.0    3003.0      3
# 9968   4.0  1200000.0    3149.0      3
# 10288  1.0   762000.0    3146.0      2
# 11503  2.0  2800000.0    3205.0      3
# 12158  1.0  2200000.0    3205.0      3

# %%
melb_x.isnull().sum(axis = 0)
# Out:
# Regionname         0
# Suburb             0
# Type               0
# YearBuilt          0
# BuildingArea    1318
# Car                0
# Price              0
# Postcode           0
# Rooms              0
# dtype: int64

# %%
#melb_newc = melb_newcc[(melb_newcc['YearBuilt']!=1196) & (melb_newcc['YearBuilt']!=1830) & (melb_newcc['YearBuilt']!=1850) ]

# %%
melb_newc = melb_newcc[(melb_newcc['YearBuilt']!=1196)]

# %%
melb_newc
# Out:
#                        Regionname         Suburb Type  YearBuilt  \
# 0           Northern Metropolitan     Abbotsford    h        NaN
# 1           Northern Metropolitan     Abbotsford    h     1900.0
# 2           Northern Metropolitan     Abbotsford    h     1900.0
# 3           Northern Metropolitan     Abbotsford    h        NaN
# 4           Northern Metropolitan     Abbotsford    h     2014.0
# ...                           ...            ...  ...        ...
# 13575  South-Eastern Metropolitan  Wheelers Hill    h     1981.0
# 13576        Western Metropolitan   Williamstown    h     1995.0
# 13577        Western Metropolitan   Williamstown    h     1997.0
# 13578        Western Metropolitan   Williamstown    h     1920.0
# 13579        Western Metropolitan     Yarraville    h     1920.0
#
#        BuildingArea  Car      Price  Postcode  Rooms
# 0               NaN  1.0  1480000.0    3067.0      2
# 1              79.0  0.0  1035000.0    3067.0      2
# 2             150.0  0.0  1465000.0    3067.0      3
# 3               NaN  1.0   850000.0    3067.0      3
# 4             142.0  2.0  1600000.0    3067.0      4
# ...             ...  ...        ...       ...    ...
# 13575           NaN  2.0  1245000.0    3150.0      4
# 13576         133.0  2.0  1031000.0    3016.0      3
# 13577           NaN  4.0  1170000.0    3016.0      3
# 13578         157.0  5.0  2500000.0    3016.0      4
# 13579         112.0  1.0  1285000.0    3013.0      4
#
# [13255 rows x 9 columns]

# %%
melb_newc.isnull().sum(axis = 0)
# Out:
# Regionname         0
# Suburb             0
# Type               0
# YearBuilt       5252
# BuildingArea    6313
# Car                0
# Price              0
# Postcode           0
# Rooms              0
# dtype: int64

# %%
#Histograma de la base de datos melb_new
plt.figure(figsize=(15,6))
sns.histplot(melb_newc.YearBuilt, bins=100, color ='red')
plt.ticklabel_format(style='plain')
sns.despine()

# %%
plt.figure(figsize=(15,6))
sns.histplot(melb_newc.Price, bins=100, color ='red')
plt.ticklabel_format(style='plain')
sns.despine()

# %% [markdown]
# 2. Agregar información adicional respectiva al entorno de una propiedad a partir del [conjunto de datos de AirBnB](https://www.kaggle.com/tylerx/melbourne-airbnb-open-data?select=cleansed_listings_dec18.csv) utilizado en el práctico.
#   1. Seleccionar qué variables agregar y qué combinaciones aplicar a cada una. Por ejemplo, pueden utilizar solo la columna `price`, o aplicar múltiples transformaciones como la mediana o el mínimo.

# %%
# Seleccionamos las variables a agregar
interesting_features = ['zipcode','price', 'weekly_price', 'monthly_price']
AirB = pd.read_csv('https://cs.famaf.unc.edu.ar/~mteruel/datasets/diplodatos/cleansed_listings_dec18.csv', usecols=interesting_features)
# Out:
# /usr/local/lib/python3.7/dist-packages/IPython/core/interactiveshell.py:2718: DtypeWarning: Columns (35) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
# Filtramos las columnas correspondientes a las variables seleccionadas y luego realizamos la agregación agrupando por zipcode.
# La operación conlleva pasar como argumento el nombre de la nueva columna y como valor una tupla donde el primer valor es el nombre de la
# columna original y el segundo valor es la operación de agregación que nos interesa.
AirB_agg = AirB[interesting_features].groupby('zipcode').agg(AirB_record_count=('price', 'count'),
        AirB_daily_price_mean=('price', 'mean'),
        AirB_weekly_price_mean=('weekly_price', 'mean'),
        AirB_monthly_price_mean=('monthly_price', 'mean'))\
        .reset_index()

# %%
AirB_agg.head()
# Out:
#   zipcode  AirB_record_count  AirB_daily_price_mean  AirB_weekly_price_mean  \
# 0  2010.0                  1               40.00000                     NaN
# 1  2134.0                  1               50.00000                     NaN
# 2  2582.0                  1              104.00000                     NaN
# 3  3000.0               2491              149.23605                   804.0
# 4  3001.0                  1              120.00000                     NaN
#
#    AirB_monthly_price_mean
# 0                      NaN
# 1                      NaN
# 2                      NaN
# 3                   3469.0
# 4                      NaN

# %% [markdown]
# 1. Utilizar la variable zipcode para unir los conjuntos de datos. Sólo incluir los zipcodes que tengan una cantidad mínima de registros (a elección) como para que la información agregada sea relevante.

# %%
# Seleccionamos los zipcodes que tienen al menos 3 registros en un compromiso entre contar con suficientes datos sin perder demasiados zipcodes 
AirB_aggClean = AirB_agg[AirB_agg['AirB_record_count']>2]
print(len(AirB_agg))
print(len(AirB_aggClean))
# Out:
# 463
# 396

# %%
# Convertimos zipcode de object a float64 para que coincidan los dtypes al realizar el merge
AirB_aggClean['zipcode'] = AirB_aggClean['zipcode'].astype(float, errors = 'raise')
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
# Unimos los datasets
Merge_df = melb_newc.merge(AirB_aggClean, how='left', left_on='Postcode', right_on='zipcode')
Merge_df
# Out:
#                   Regionname        Suburb Type  YearBuilt  BuildingArea  Car  \
# 0      Northern Metropolitan    Abbotsford    h        NaN           NaN  1.0
# 1      Northern Metropolitan    Abbotsford    h        NaN           NaN  1.0
# 2      Northern Metropolitan    Abbotsford    h     1900.0          79.0  0.0
# 3      Northern Metropolitan    Abbotsford    h     1900.0          79.0  0.0
# 4      Northern Metropolitan    Abbotsford    h     1900.0         150.0  0.0
# ...                      ...           ...  ...        ...           ...  ...
# 25733   Western Metropolitan  Williamstown    h     1997.0           NaN  4.0
# 25734   Western Metropolitan  Williamstown    h     1920.0         157.0  5.0
# 25735   Western Metropolitan  Williamstown    h     1920.0         157.0  5.0
# 25736   Western Metropolitan    Yarraville    h     1920.0         112.0  1.0
# 25737   Western Metropolitan    Yarraville    h     1920.0         112.0  1.0
#
#            Price  Postcode  Rooms  zipcode  AirB_record_count  \
# 0      1480000.0    3067.0      2   3067.0              157.0
# 1      1480000.0    3067.0      2   3067.0              101.0
# 2      1035000.0    3067.0      2   3067.0              157.0
# 3      1035000.0    3067.0      2   3067.0              101.0
# 4      1465000.0    3067.0      3   3067.0              157.0
# ...          ...       ...    ...      ...                ...
# 25733  1170000.0    3016.0      3   3016.0               20.0
# 25734  2500000.0    3016.0      4   3016.0               54.0
# 25735  2500000.0    3016.0      4   3016.0               20.0
# 25736  1285000.0    3013.0      4   3013.0               42.0
# 25737  1285000.0    3013.0      4   3013.0               40.0
#
#        AirB_daily_price_mean  AirB_weekly_price_mean  AirB_monthly_price_mean
# 0                 140.292994              236.250000               956.363636
# 1                 115.594059              735.352941              2863.900000
# 2                 140.292994              236.250000               956.363636
# 3                 115.594059              735.352941              2863.900000
# 4                 140.292994              236.250000               956.363636
# ...                      ...                     ...                      ...
# 25733             167.200000              633.000000              2163.000000
# 25734             199.944444              550.000000              1990.000000
# 25735             167.200000              633.000000              2163.000000
# 25736             127.523810                     NaN                      NaN
# 25737             144.100000              923.571429              2966.090909
#
# [25738 rows x 14 columns]

# %% [markdown]
# ## Ejercicio 3:
#
# Crear y guardar un nuevo conjunto de datos con todas las transformaciones realizadas anteriormente.

# %%
from google.colab import files

Merge_df.to_csv('Merge_df.csv', index=None)
files.download('Merge_df.csv')

# %% [markdown]
# ## Ejercicios opcionales:
#
# 1. Armar un script en python (archivo .py) [ETL](https://towardsdatascience.com/what-to-log-from-python-etl-pipelines-9e0cfe29950e) que corra los pasos de extraccion, transformacion y carga, armando una funcion para cada etapa del proceso y luego un main que corra todos los pasos requeridos.
#
# 2. Armar un DAG en Apache Airflow que corra el ETL. (https://airflow.apache.org/docs/apache-airflow/stable/tutorial.html)
